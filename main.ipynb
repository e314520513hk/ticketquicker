# %%
# from selenium import  webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.common.by import By
# from time import sleep
# from selenium.webdriver.support.wait import WebDriverWait
# from selenium.webdriver.support import expected_conditions as EC
# from selenium.webdriver.common.action_chains import ActionChains
# import os
# import sys
# import configparser

# cf = configparser.ConfigParser()
# cf.read("config.ini")

# # secs = cf.sections()

# # print(secs)
# # options = cf.options("account_info")
# # print(options)

# # items =  cf.items("account_info")
# # print(items)


# s = Service(r"./chromedriver")

# driver = webdriver.Chrome(service=s)
# driver.set_window_size(1080, 768)
# # driver.implicitly_wait(100)

# driver.get('https://tixcraft.com/')   

# print(driver.title)
# WebDriverWait(driver, 10, 1).until(EC.visibility_of_element_located((By.XPATH,'//*[@id="onetrust-accept-btn-handler"]')))
# driver.find_element(By.XPATH,'//*[@id="onetrust-accept-btn-handler"]').click()


# # 動作:登入
# WebDriverWait(driver, 10, 1).until(EC.visibility_of_element_located((By.XPATH,'/html/body/div[1]/div[1]/div[2]/div[1]/div/div[2]/div/ul/li[3]/a')))
# driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div[1]/div/div[2]/div/ul/li[3]/a').click()
# WebDriverWait(driver, 10, 1).until(EC.visibility_of_element_located((By.XPATH,'//*[@id="loginFacebook"]')))
# driver.find_element(By.XPATH,'//*[@id="loginFacebook"]').click()
# WebDriverWait(driver, 10, 1).until(EC.visibility_of_element_located((By.XPATH,'//*[@id="email"]')))
# driver.find_element(By.XPATH,'//*[@id="email"]').send_keys(cf.get("account_info","username"))
# WebDriverWait(driver, 10, 1).until(EC.visibility_of_element_located((By.XPATH,'//*[@id="pass"]')))
# driver.find_element(By.XPATH,'//*[@id="pass"]').send_keys(cf.get("account_info","password"))
# WebDriverWait(driver, 10, 1).until(EC.visibility_of_element_located((By.XPATH,'//*[@id="loginbutton"]')))
# driver.find_element(By.XPATH,'//*[@id="loginbutton"]').click()

# #立即購票按鈕
# locator1 = (By.XPATH ,'//*[@id="content"]/div/div/ul/li[1]/a/div')
# locator2 = (By.LINK_TEXT ,'立即購票')
# locator3 = (By.XPATH ,'//*[@id="gameList"]/table/tbody/tr/td[4]/input')

# try:
#     WebDriverWait(driver, 120, 1).until(EC.presence_of_element_located(locator1)) #最長等待10秒，每0.5秒檢查一次條件是否成立
#     WebDriverWait(driver, 120, 1).until(EC.presence_of_element_located(locator2)) #最長等待10秒，每0.5秒檢查一次條件是否成立
#     print("已進入購票頁")
# except:
#     print("逾時，未進入購票頁")

# print("開始購票")
    



# while True:
    
    
    
#     try:
#         driver.find_element(By.XPATH ,'//*[@id="content"]/div/div/ul/li[1]/a/div').click()
        
#         sleep(0.5)
       
#         driver.find_element(By.XPATH ,'//*[@id="gameList"]/table/tbody/tr/td[4]/input').click()
#         break
#     except:
#         continue
        
    
    

# print("選擇座位")    
# while True:
#     try:
        
#         ticketList = driver.find_elements(By.CSS_SELECTOR ,'div.zone.area-list > ul')
        
#         print(len(ticketList))
#         for x in range(len(ticketList)):
        
#             if "熱賣中" in ticketList[x].text:
#                 print("熱賣中")
#                 ticketList[x].click()
#             elif "剩餘" in ticketList[x].text:   
#                 print(ticketList[x].text + "門票剩餘"+ticketList[x].text.split()[2])
#                 print(int(ticketList[x].text.split()[2]))
#                 print(int(cf.get("ticket_info","amount")))
#                 if int(cf.get("ticket_info","amount")) <= int(ticketList[x].text.split()[2]):
#                     ticketList[x].click()
#                 else:
#                     continue
#             else:
#                 print(ticketList[x].text + "沒票")
#                 continue
    
       

#         #輸入驗證碼頁面
#         driver.find_element(By.XPATH ,'//*[@id="TicketForm_ticketPrice_01"]/option[text()="'+cf.get("ticket_info","amount")+'"]').click()        
#         driver.find_element(By.XPATH ,'//*[@id="TicketForm_agree"]').click()        

#         toElement = driver.find_element(By.ID ,'TicketForm_verifyCode').click()        

#         ActionChains(driver).move_to_element(toElement)
        
   
    
#     finally:
#         break
# Out:
# tixCraft拓元售票系統
# 已進入購票頁
# 開始購票
# 選擇座位
# 1
# 熱賣中
